# %%
import datetime 
class Usuario:
  def __init__(self):
    self.nombre=input("Ingrese su nombre: ")
    self.cc=int(input("Ingrese su Cedula: "))
    self.edad=int(input("Ingrese su edad: "))
    self.celular=int(input("Ingrese su celular: "))


class Libro(Usuario ):
  def  __init__(self):
    super().__init__()
    self.fecha=["16 agosto 2004","15 marzo 2010","8 octubre  1995","22 diciembre 2000"]
    self.titulo=["Los cuatro acuerdos", "Escucha tu subconsiente", "Yurupari", "El tunel"]
    self.autor=["Miguel Ruiz","Jenny Davidow","Ermanno Stradelli","Ernesto  Sabato"]
    self.ISBN=["4578962315489-P","625935489565-Y","7845655522369-R","1230689472156-Q"]
    self.edicion=["1a Edicion","5a Edicion","8a Edicion","10a Edicion"]
    self.lugar=["Teotihuacan (MEX)","Bogota, Cundinamarca (COL)","Buenos Aires (ARG)","Madrid(ESP)"]
    self.paginas=[200,365,140,95]

  def Main(self):
    print("BIenvenido", self.nombre)
    print("1.Mostrar info")
    print("2.Prestar libro")
    opc=int(input("Que desea hacer? "))
    print("LIBROS DISPONIBLES")
    contador=1
    for i in self.titulo:
      print(contador, i)
      contador= contador+1
    if opc==1:
      x.Mostrar_info()
    elif opc==2:
      x.prestar()
    else:
      print("opcion no valida")
      x.Main()
     
  def Mostrar_info(self):
    opc=int(input("Digite posicion del libro "))
    if  opc==1:
      print("Titulo: ",self.titulo[0])
      print(self.edicion[0])
      print("Autor: ",self.autor[0])
      print("ISBN: ",self.ISBN[0])
      print(self.lugar[0])
      print(self.paginas[0]," Paginas")
      print(self.fecha[0])
      x.Main()
    elif  opc==2:
      print("Titulo: ",self.titulo[1])
      print(self.edicion[1])
      print("Autor: ",self.autor[1])
      print("ISBN: ",self.ISBN[1])
      print(self.lugar[1])
      print(self.paginas[1]," Paginas")
      print(self.fecha[1])
      x.Main()
    elif  opc==3:
      print("Titulo: ",self.titulo[2])
      print(self.edicion[2])
      print("Autor: ",self.autor[2])
      print("ISBN: ",self.ISBN[2])
      print(self.lugar[2])
      print(self.paginas[2]," Paginas")
      print(self.fecha[2])
      x.Main()
    elif  opc==4:
      print("Titulo: ",self.titulo[3])
      print(self.edicion[3])
      print("Autor: ",self.autor[3])
      print("ISBN: ",self.ISBN[3])
      print(self.lugar[3])
      print(self.paginas[3]," Paginas")
      print(self.fecha[3])
      x.Main()
    else:
      print("fuera de stock")

  def prestar(self):
    opc=int(input("Ingrese el libro: "))
    if  opc==1:
      print("Titulo: ",self.titulo[0])
      print("Gracias por visitarnos")
      print( f"Devolver el dia: {datetime.datetime.now().day}/{datetime.datetime.now().month- 1}/{1+datetime.datetime.now().year}")
      exit()
    if  opc==2:
      print("Titulo: ",self.titulo[1])
      print("Gracias por visitarnos")
      print( f"Devolver el dia: {datetime.datetime.now().day}/{datetime.datetime.now().month- 1}/{1+datetime.datetime.now().year}")
      exit()
    if  opc==3:
      print("Titulo: ",self.titulo[2])
      print("Gracias por visitarnos")
      print( f"Devolver el dia: {datetime.datetime.now().day}/{datetime.datetime.now().month- 1}/{1+datetime.datetime.now().year}")
      exit()
    if  opc==4:
      print("Titulo: ",self.titulo[3])
      print("Gracias por visitarnos")
      print( f"Devolver el dia: {datetime.datetime.now().day}/{datetime.datetime.now().month- 1}/{1+datetime.datetime.now().year}")
      exit()
    
x=Libro()
x.Main()
